# %% [markdown]
# # Using Fast API to create an API for your ML Deployment

# %%
from fastapi import FastAPI
from pydantic import BaseModel

app = FastAPI()

# %% [markdown]
# # Declare Pydantic Object for API

# %%
class InputData(BaseModel):
    feature1: float
    feature2: float
    feature3: float
    feature4: float

# %% [markdown]
# # Import our ML model from earlier.

# %%
import mlflow.sklearn

# Load the model (replace with your model path)
model = mlflow.sklearn.load_model("runs:/" + best_run_id + "/model")
# Out:
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# Cell In[7], line 4
#       1 import mlflow.sklearn
#       3 # Load the model (replace with your model path)
# ----> 4 model = mlflow.sklearn.load_model("runs:/" + best_run_id + "/model")
#
# File ~/anaconda3/envs/myenv/lib/python3.8/site-packages/mlflow/sklearn/__init__.py:613, in load_model(model_uri, dst_path)
#     580 def load_model(model_uri, dst_path=None):
#     581     """
#     582     Load a scikit-learn model from a local file or a run.
#     583
#    (...)
#     611         predictions = sk_model.predict(pandas_df)
#     612     """
# --> 613     local_model_path = _download_artifact_from_uri(artifact_uri=model_uri, output_path=dst_path)
#     614     flavor_conf = _get_flavor_configuration(model_path=local_model_path, flavor_name=FLAVOR_NAME)
# ...

# %%
best_run = mlflow.search_runs(order_by=["metrics.accuracy desc"]).iloc[0]
best_run_id = best_run.run_id
best_model = mlflow.sklearn.load_model("runs:/" + best_run_id + "/model")
# Out:
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# Cell In[6], line 3
#       1 best_run = mlflow.search_runs(order_by=["metrics.accuracy desc"]).iloc[0]
#       2 best_run_id = best_run.run_id
# ----> 3 best_model = mlflow.sklearn.load_model("runs:/" + best_run_id + "/model")
#
# File ~/anaconda3/envs/myenv/lib/python3.8/site-packages/mlflow/sklearn/__init__.py:613, in load_model(model_uri, dst_path)
#     580 def load_model(model_uri, dst_path=None):
#     581     """
#     582     Load a scikit-learn model from a local file or a run.
#     583
#    (...)
#     611         predictions = sk_model.predict(pandas_df)
#     612     """
# --> 613     local_model_path = _download_artifact_from_uri(artifact_uri=model_uri, output_path=dst_path)
#     614     flavor_conf = _get_flavor_configuration(model_path=local_model_path, flavor_name=FLAVOR_NAME)
# ...
